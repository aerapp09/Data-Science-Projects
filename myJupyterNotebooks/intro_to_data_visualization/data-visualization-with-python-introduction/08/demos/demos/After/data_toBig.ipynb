# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
data = pd.read_csv('obama.csv', parse_dates=['year_month'])
data.head()
# Out:
#   year_month  survey_organization  approve_percent  disapprove_percent
# 0 2009-01-01             ABC/Post             80.0                15.0
# 1 2009-01-01               AP-GFK             74.0                15.0
# 2 2009-01-01                  CNN             84.0                14.0
# 3 2009-01-01  Democracy Corps (D)             51.0                20.0
# 4 2009-01-01       Diageo/Hotline             64.0                 6.5

# %%
plt.plot(data.year_month, data.approve_percent, 'o', markersize=2, alpha= 0.3)

# %%
data_mean = data.groupby('year_month').mean()
data_median = data.groupby('year_month').median()
plt.plot(data_mean.index, data_mean.approve_percent, 'red')
plt.plot(data_median.index, data_median.approve_percent, 'green')
plt.legend(['Mean', 'Median'])

plt.plot(data.year_month, data.approve_percent, 'o', markersize=2, alpha= 0.3)
# Out:
# C:\Users\aerap\AppData\Local\Temp\ipykernel_13032\542922872.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data_mean = data.groupby('year_month').mean()
# C:\Users\aerap\AppData\Local\Temp\ipykernel_13032\542922872.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.median is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data_median = data.groupby('year_month').median()

# %%
data_25 = data.groupby('year_month').quantile(0.25)
data_75 = data.groupby('year_month').quantile(0.75)

plt.plot(data_75.index, data_75.approve_percent, 'green')
plt.plot(data_median.index, data_median.approve_percent, 'red')
plt.plot(data_25.index, data_25.approve_percent, 'blue')
plt.plot(data.year_month, data.approve_percent, 'o', markersize = 2, alpha = 0.3)
plt.legend(['75th percentile', 'Median', '25th percentile'])
# Out:
# C:\Users\aerap\AppData\Local\Temp\ipykernel_13032\872141350.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.quantile is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data_25 = data.groupby('year_month').quantile(0.25)
# C:\Users\aerap\AppData\Local\Temp\ipykernel_13032\872141350.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.quantile is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data_75 = data.groupby('year_month').quantile(0.75)
