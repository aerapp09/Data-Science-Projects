# %%
import pandas as pd

# %%
data = pd.read_csv('Realestate.csv')

# %%
data.head()
# Out:
#    No  transaction  houseAge  distanceToNearestMRTstation  \
# 0   1     2012.917      32.0                     84.87882
# 1   2     2012.917      19.5                    306.59470
# 2   3     2013.583      13.3                    561.98450
# 3   4     2013.500      13.3                    561.98450
# 4   5     2012.833       5.0                    390.56840
#
#    numberOfConvenienceStores  latitude  longitude  housePriceOfUnitArea
# 0                         10  24.98298  121.54024                   NaN
# 1                          9  24.98034  121.53951                  42.2
# 2                          5  24.98746  121.54391                  47.3
# 3                          5  24.98746  121.54391                  54.8
# 4                          5  24.97937  121.54245                  43.1

# %%
data.space()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 data.space()
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'space'

# %%
data.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 data.shape()
#
# TypeError: 'tuple' object is not callable

# %%
data.shape
# Out:
# (418, 8)

# %%
data.dtypes
# Out:
# No                               int64
# transaction                    float64
# houseAge                       float64
# distanceToNearestMRTstation    float64
# numberOfConvenienceStores        int64
# latitude                       float64
# longitude                      float64
# housePriceOfUnitArea           float64
# dtype: object

# %%
data.houseAge.mean()
# Out:
# 17.620334928229664

# %%
data.houseAge
# Out:
# 0      32.0
# 1      19.5
# 2      13.3
# 3      13.3
# 4       5.0
#        ...
# 413    13.7
# 414     5.6
# 415    18.8
# 416     8.1
# 417     6.5
# Name: houseAge, Length: 418, dtype: float64

# %%
data.houseAge.min()
# Out:
# 0.0

# %%
data.houseAge.max()
# Out:
# 43.8

# %%
data.houseAge.std()
# Out:
# 11.428348063298536

# %%
age = data.houseAge

# %%
norm = (age - age.mean()) / age.std()

# %%
norm
# Out:
# 0      1.258245
# 1      0.164474
# 2     -0.378037
# 3     -0.378037
# 4     -1.104301
#          ...
# 413   -0.343036
# 414   -1.051800
# 415    0.103223
# 416   -0.833046
# 417   -0.973048
# Name: houseAge, Length: 418, dtype: float64

# %%
minxmax = (age - age.min()) / (age.max() - age.min())

# %%
minmax
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 minmax
#
# NameError: name 'minmax' is not defined

# %%
age
# Out:
# 0      32.0
# 1      19.5
# 2      13.3
# 3      13.3
# 4       5.0
#        ...
# 413    13.7
# 414     5.6
# 415    18.8
# 416     8.1
# 417     6.5
# Name: houseAge, Length: 418, dtype: float64

# %%
minxmax = minmax
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 minxmax = minmax
#
# NameError: name 'minmax' is not defined

# %%
minxmax
# Out:
# 0      0.730594
# 1      0.445205
# 2      0.303653
# 3      0.303653
# 4      0.114155
#          ...
# 413    0.312785
# 414    0.127854
# 415    0.429224
# 416    0.184932
# 417    0.148402
# Name: houseAge, Length: 418, dtype: float64

# %%
minxmax= 'minmax'

# %%
minmax
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 minmax
#
# NameError: name 'minmax' is not defined

# %%
minmax = (age - age.min()) / (age.max() - age.min()) ##2/2 types of normalizing data or standardization

# %%
minmax ##this makes it so that values are between 0 and 1. By finding min it will be 0 and max is 1
# Out:
# 0      0.730594
# 1      0.445205
# 2      0.303653
# 3      0.303653
# 4      0.114155
#          ...
# 413    0.312785
# 414    0.127854
# 415    0.429224
# 416    0.184932
# 417    0.148402
# Name: houseAge, Length: 418, dtype: float64

# %%
data['standardized_age'] = norm ##creating column name and setting to norm variabel

# %%
data.head()
# Out:
#    No  transaction  houseAge  distanceToNearestMRTstation  \
# 0   1     2012.917      32.0                     84.87882
# 1   2     2012.917      19.5                    306.59470
# 2   3     2013.583      13.3                    561.98450
# 3   4     2013.500      13.3                    561.98450
# 4   5     2012.833       5.0                    390.56840
#
#    numberOfConvenienceStores  latitude  longitude  housePriceOfUnitArea  \
# 0                         10  24.98298  121.54024                   NaN
# 1                          9  24.98034  121.53951                  42.2
# 2                          5  24.98746  121.54391                  47.3
# 3                          5  24.98746  121.54391                  54.8
# 4                          5  24.97937  121.54245                  43.1
#
#    standardized_age
# 0          1.258245
# 1          0.164474
# 2         -0.378037
# 3         -0.378037
# 4         -1.104301

# %%
data.age = minmax
# Out:
# C:\Users\aerap\AppData\Local\Temp\ipykernel_13980\731971030.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   data.age = minmax

# %%
minmax
# Out:
# 0      0.730594
# 1      0.445205
# 2      0.303653
# 3      0.303653
# 4      0.114155
#          ...
# 413    0.312785
# 414    0.127854
# 415    0.429224
# 416    0.184932
# 417    0.148402
# Name: houseAge, Length: 418, dtype: float64

# %%
data.age
# Out:
# 0      0.730594
# 1      0.445205
# 2      0.303653
# 3      0.303653
# 4      0.114155
#          ...
# 413    0.312785
# 414    0.127854
# 415    0.429224
# 416    0.184932
# 417    0.148402
# Name: houseAge, Length: 418, dtype: float64

# %%
date.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 date.head()
#
# NameError: name 'date' is not defined

# %%
data.head()
# Out:
#    No  transaction  houseAge  distanceToNearestMRTstation  \
# 0   1     2012.917      32.0                     84.87882
# 1   2     2012.917      19.5                    306.59470
# 2   3     2013.583      13.3                    561.98450
# 3   4     2013.500      13.3                    561.98450
# 4   5     2012.833       5.0                    390.56840
#
#    numberOfConvenienceStores  latitude  longitude  housePriceOfUnitArea  \
# 0                         10  24.98298  121.54024                   NaN
# 1                          9  24.98034  121.53951                  42.2
# 2                          5  24.98746  121.54391                  47.3
# 3                          5  24.98746  121.54391                  54.8
# 4                          5  24.97937  121.54245                  43.1
#
#    standardized_age
# 0          1.258245
# 1          0.164474
# 2         -0.378037
# 3         -0.378037
# 4         -1.104301

# %%
data.age
# Out:
# 0      0.730594
# 1      0.445205
# 2      0.303653
# 3      0.303653
# 4      0.114155
#          ...
# 413    0.312785
# 414    0.127854
# 415    0.429224
# 416    0.184932
# 417    0.148402
# Name: houseAge, Length: 418, dtype: float64

# %%
data.houseAge
# Out:
# 0      32.0
# 1      19.5
# 2      13.3
# 3      13.3
# 4       5.0
#        ...
# 413    13.7
# 414     5.6
# 415    18.8
# 416     8.1
# 417     6.5
# Name: houseAge, Length: 418, dtype: float64

# %%
data.houseAge= minmax

# %%
data.head()
# Out:
#    No  transaction  houseAge  distanceToNearestMRTstation  \
# 0   1     2012.917  0.730594                     84.87882
# 1   2     2012.917  0.445205                    306.59470
# 2   3     2013.583  0.303653                    561.98450
# 3   4     2013.500  0.303653                    561.98450
# 4   5     2012.833  0.114155                    390.56840
#
#    numberOfConvenienceStores  latitude  longitude  housePriceOfUnitArea  \
# 0                         10  24.98298  121.54024                   NaN
# 1                          9  24.98034  121.53951                  42.2
# 2                          5  24.98746  121.54391                  47.3
# 3                          5  24.98746  121.54391                  54.8
# 4                          5  24.97937  121.54245                  43.1
#
#    standardized_age
# 0          1.258245
# 1          0.164474
# 2         -0.378037
# 3         -0.378037
# 4         -1.104301

# %%
minmax
# Out:
# 0      0.730594
# 1      0.445205
# 2      0.303653
# 3      0.303653
# 4      0.114155
#          ...
# 413    0.312785
# 414    0.127854
# 415    0.429224
# 416    0.184932
# 417    0.148402
# Name: houseAge, Length: 418, dtype: float64

# %%
data.rename('standardized_age'= 'houseAgeStandardized')
# Out:
#   Cell In[37], line 1
#     data.rename('standardized_age'= 'houseAgeStandardized')
#                 ^
# SyntaxError: expression cannot contain assignment, perhaps you meant "=="?

# %%
data.rename(standardized_age= 'houseAgeStandardized')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 data.rename(standardized_age= 'houseAgeStandardized')
#
# TypeError: DataFrame.rename() got an unexpected keyword argument 'standardized_age'

# %%
data.rename(columns={'standardized_age': 'houseAgeStandardized'})
# Out:
#       No  transaction  houseAge  distanceToNearestMRTstation  \
# 0      1     2012.917  0.730594                     84.87882
# 1      2     2012.917  0.445205                    306.59470
# 2      3     2013.583  0.303653                    561.98450
# 3      4     2013.500  0.303653                    561.98450
# 4      5     2012.833  0.114155                    390.56840
# ..   ...          ...       ...                          ...
# 413  410     2013.000  0.312785                   4082.01500
# 414  411     2012.667  0.127854                     90.45606
# 415  412     2013.250  0.429224                    390.96960
# 416  413     2013.000  0.184932                    104.81010
# 417  414     2013.500  0.148402                     90.45606
#
#      numberOfConvenienceStores  latitude  longitude  housePriceOfUnitArea  \
# 0                           10  24.98298  121.54024                   NaN
# 1                            9  24.98034  121.53951                  42.2
# ...

# %%
data.standarized_age= data.rename(columns={'standardized_age': 'houseAgeStandardized'})
# Out:
# C:\Users\aerap\AppData\Local\Temp\ipykernel_13980\2086637468.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   data.standarized_age= data.rename(columns={'standardized_age': 'houseAgeStandardized'})

# %%
data.rename(columns={'standardized_age': 'houseAgeStandardized'}, inplace =True) ##rename column

# %%
data.head()
# Out:
#    No  transaction  houseAge  distanceToNearestMRTstation  \
# 0   1     2012.917  0.730594                     84.87882
# 1   2     2012.917  0.445205                    306.59470
# 2   3     2013.583  0.303653                    561.98450
# 3   4     2013.500  0.303653                    561.98450
# 4   5     2012.833  0.114155                    390.56840
#
#    numberOfConvenienceStores  latitude  longitude  housePriceOfUnitArea  \
# 0                         10  24.98298  121.54024                   NaN
# 1                          9  24.98034  121.53951                  42.2
# 2                          5  24.98746  121.54391                  47.3
# 3                          5  24.98746  121.54391                  54.8
# 4                          5  24.97937  121.54245                  43.1
#
#    houseAgeStandardized
# 0              1.258245
# 1              0.164474
# 2             -0.378037
# 3             -0.378037
# 4             -1.104301

# %%
data.drop(0)
# Out:
#       No  transaction  houseAge  distanceToNearestMRTstation  \
# 1      2     2012.917  0.445205                    306.59470
# 2      3     2013.583  0.303653                    561.98450
# 3      4     2013.500  0.303653                    561.98450
# 4      5     2012.833  0.114155                    390.56840
# 5      6     2012.667  0.162100                   2175.03000
# ..   ...          ...       ...                          ...
# 413  410     2013.000  0.312785                   4082.01500
# 414  411     2012.667  0.127854                     90.45606
# 415  412     2013.250  0.429224                    390.96960
# 416  413     2013.000  0.184932                    104.81010
# 417  414     2013.500  0.148402                     90.45606
#
#      numberOfConvenienceStores  latitude  longitude  housePriceOfUnitArea  \
# 1                            9  24.98034  121.53951                  42.2
# 2                            5  24.98746  121.54391                  47.3
# ...

# %%
data.drop('id')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 data.drop('id')
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5252 def drop(  # type: ignore[override]
#    5253     self,
#    (...)
#    5260     errors: IgnoreRaise = "raise",
# ...

# %%
data.drop('id', axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 data.drop('id', axis=1)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5252 def drop(  # type: ignore[override]
#    5253     self,
#    (...)
# ...

# %%
data.drop('No', axis= 1)
# Out:
#      transaction  houseAge  distanceToNearestMRTstation  \
# 0       2012.917  0.730594                     84.87882
# 1       2012.917  0.445205                    306.59470
# 2       2013.583  0.303653                    561.98450
# 3       2013.500  0.303653                    561.98450
# 4       2012.833  0.114155                    390.56840
# ..           ...       ...                          ...
# 413     2013.000  0.312785                   4082.01500
# 414     2012.667  0.127854                     90.45606
# 415     2013.250  0.429224                    390.96960
# 416     2013.000  0.184932                    104.81010
# 417     2013.500  0.148402                     90.45606
#
#      numberOfConvenienceStores  latitude  longitude  housePriceOfUnitArea  \
# 0                           10  24.98298  121.54024                   NaN
# 1                            9  24.98034  121.53951                  42.2
# ...

# %%
data.head()
# Out:
#    No  transaction  houseAge  distanceToNearestMRTstation  \
# 0   1     2012.917  0.730594                     84.87882
# 1   2     2012.917  0.445205                    306.59470
# 2   3     2013.583  0.303653                    561.98450
# 3   4     2013.500  0.303653                    561.98450
# 4   5     2012.833  0.114155                    390.56840
#
#    numberOfConvenienceStores  latitude  longitude  housePriceOfUnitArea  \
# 0                         10  24.98298  121.54024                   NaN
# 1                          9  24.98034  121.53951                  42.2
# 2                          5  24.98746  121.54391                  47.3
# 3                          5  24.98746  121.54391                  54.8
# 4                          5  24.97937  121.54245                  43.1
#
#    houseAgeStandardized
# 0              1.258245
# 1              0.164474
# 2             -0.378037
# 3             -0.378037
# 4             -1.104301

# %%
data.drop('numberOfConvenienceStores', axis=1)
# Out:
#       No  transaction  houseAge  distanceToNearestMRTstation  latitude  \
# 0      1     2012.917  0.730594                     84.87882  24.98298
# 1      2     2012.917  0.445205                    306.59470  24.98034
# 2      3     2013.583  0.303653                    561.98450  24.98746
# 3      4     2013.500  0.303653                    561.98450  24.98746
# 4      5     2012.833  0.114155                    390.56840  24.97937
# ..   ...          ...       ...                          ...       ...
# 413  410     2013.000  0.312785                   4082.01500  24.94155
# 414  411     2012.667  0.127854                     90.45606  24.97433
# 415  412     2013.250  0.429224                    390.96960  24.97923
# 416  413     2013.000  0.184932                    104.81010  24.96674
# 417  414     2013.500  0.148402                     90.45606  24.97433
#
#      longitude  housePriceOfUnitArea  houseAgeStandardized
# ...

# %%
data.drop('numberOfConvenienceStores', axis=1, inplace=True) ##drop this column axis=1 refers to columns because default is 0 or rows

# %%
data.head()
# Out:
#    No  transaction  houseAge  distanceToNearestMRTstation  latitude  \
# 0   1     2012.917  0.730594                     84.87882  24.98298
# 1   2     2012.917  0.445205                    306.59470  24.98034
# 2   3     2013.583  0.303653                    561.98450  24.98746
# 3   4     2013.500  0.303653                    561.98450  24.98746
# 4   5     2012.833  0.114155                    390.56840  24.97937
#
#    longitude  housePriceOfUnitArea  houseAgeStandardized
# 0  121.54024                   NaN              1.258245
# 1  121.53951                  42.2              0.164474
# 2  121.54391                  47.3             -0.378037
# 3  121.54391                  54.8             -0.378037
# 4  121.54245                  43.1             -1.104301

# %%
data.drop(columns=['houseAge'])
# Out:
#       No  transaction  distanceToNearestMRTstation  latitude  longitude  \
# 0      1     2012.917                     84.87882  24.98298  121.54024
# 1      2     2012.917                    306.59470  24.98034  121.53951
# 2      3     2013.583                    561.98450  24.98746  121.54391
# 3      4     2013.500                    561.98450  24.98746  121.54391
# 4      5     2012.833                    390.56840  24.97937  121.54245
# ..   ...          ...                          ...       ...        ...
# 413  410     2013.000                   4082.01500  24.94155  121.50381
# 414  411     2012.667                     90.45606  24.97433  121.54310
# 415  412     2013.250                    390.96960  24.97923  121.53986
# 416  413     2013.000                    104.81010  24.96674  121.54067
# 417  414     2013.500                     90.45606  24.97433  121.54310
#
#      housePriceOfUnitArea  houseAgeStandardized
# 0                     NaN              1.258245
# ...

# %%
data.rename({transaction: transactionDate}, axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 data.rename({transaction: transactionDate}, axis=1)
#
# NameError: name 'transaction' is not defined

# %%
data.rename(column={transaction: transactionDate})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 data.rename(column={transaction: transactionDate})
#
# NameError: name 'transaction' is not defined

# %%
data.rename({'transaction': 'transactionDate'}, axis=1) ##trying multiple ways to find column name
# Out:
#       No  transactionDate  houseAge  distanceToNearestMRTstation  latitude  \
# 0      1         2012.917  0.730594                     84.87882  24.98298
# 1      2         2012.917  0.445205                    306.59470  24.98034
# 2      3         2013.583  0.303653                    561.98450  24.98746
# 3      4         2013.500  0.303653                    561.98450  24.98746
# 4      5         2012.833  0.114155                    390.56840  24.97937
# ..   ...              ...       ...                          ...       ...
# 413  410         2013.000  0.312785                   4082.01500  24.94155
# 414  411         2012.667  0.127854                     90.45606  24.97433
# 415  412         2013.250  0.429224                    390.96960  24.97923
# 416  413         2013.000  0.184932                    104.81010  24.96674
# 417  414         2013.500  0.148402                     90.45606  24.97433
#
#      longitude  housePriceOfUnitArea  houseAgeStandardized
# ...

# %%
data.rename({'transaction': 'transactionDate'}, axis=1, inplace=True) ##rename transaction to transactionDate

# %%
data.head()
# Out:
#    No  transactionDate  houseAge  distanceToNearestMRTstation  latitude  \
# 0   1         2012.917  0.730594                     84.87882  24.98298
# 1   2         2012.917  0.445205                    306.59470  24.98034
# 2   3         2013.583  0.303653                    561.98450  24.98746
# 3   4         2013.500  0.303653                    561.98450  24.98746
# 4   5         2012.833  0.114155                    390.56840  24.97937
#
#    longitude  housePriceOfUnitArea  houseAgeStandardized
# 0  121.54024                   NaN              1.258245
# 1  121.53951                  42.2              0.164474
# 2  121.54391                  47.3             -0.378037
# 3  121.54391                  54.8             -0.378037
# 4  121.54245                  43.1             -1.104301

# %%
data.loc[0:3, 0:2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 data.loc[0:3, 0:2]
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:1067, in _LocationIndexer.__getitem__(self, key)
#    1065     if self._is_scalar_access(key):
#    1066         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1067     return self._getitem_tuple(key)
#    1068 else:
#    1069     # we by definition only have the 0th axis
#    1070     axis = self.axis or 0
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:1256, in _LocIndexer._getitem_tuple(self, tup)
#    1253 if self._multi_take_opportunity(tup):
#    1254     return self._multi_take(tup)
# -> 1256 return self._getitem_tuple_same_dim(tup)
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:924, in _LocationIndexer._getitem_tuple_same_dim(self, tup)
# ...

# %%
data.loc[0]
# Out:
# No                                1.000000
# transactionDate                2012.917000
# houseAge                          0.730594
# distanceToNearestMRTstation      84.878820
# latitude                         24.982980
# longitude                       121.540240
# housePriceOfUnitArea                   NaN
# houseAgeStandardized              1.258245
# Name: 0, dtype: float64

# %%
data.loc[0, :]
# Out:
# No                                1.000000
# transactionDate                2012.917000
# houseAge                          0.730594
# distanceToNearestMRTstation      84.878820
# latitude                         24.982980
# longitude                       121.540240
# housePriceOfUnitArea                   NaN
# houseAgeStandardized              1.258245
# Name: 0, dtype: float64

# %%
data.loc[0:2]
# Out:
#    No  transactionDate  houseAge  distanceToNearestMRTstation  latitude  \
# 0   1         2012.917  0.730594                     84.87882  24.98298
# 1   2         2012.917  0.445205                    306.59470  24.98034
# 2   3         2013.583  0.303653                    561.98450  24.98746
#
#    longitude  housePriceOfUnitArea  houseAgeStandardized
# 0  121.54024                   NaN              1.258245
# 1  121.53951                  42.2              0.164474
# 2  121.54391                  47.3             -0.378037

# %%
data.loc[0:2, :]
# Out:
#    No  transactionDate  houseAge  distanceToNearestMRTstation  latitude  \
# 0   1         2012.917  0.730594                     84.87882  24.98298
# 1   2         2012.917  0.445205                    306.59470  24.98034
# 2   3         2013.583  0.303653                    561.98450  24.98746
#
#    longitude  housePriceOfUnitArea  houseAgeStandardized
# 0  121.54024                   NaN              1.258245
# 1  121.53951                  42.2              0.164474
# 2  121.54391                  47.3             -0.378037

# %%
data.loc[0:2]
# Out:
#    No  transactionDate  houseAge  distanceToNearestMRTstation  latitude  \
# 0   1         2012.917  0.730594                     84.87882  24.98298
# 1   2         2012.917  0.445205                    306.59470  24.98034
# 2   3         2013.583  0.303653                    561.98450  24.98746
#
#    longitude  housePriceOfUnitArea  houseAgeStandardized
# 0  121.54024                   NaN              1.258245
# 1  121.53951                  42.2              0.164474
# 2  121.54391                  47.3             -0.378037

# %%
data[0:2]
# Out:
#    No  transactionDate  houseAge  distanceToNearestMRTstation  latitude  \
# 0   1         2012.917  0.730594                     84.87882  24.98298
# 1   2         2012.917  0.445205                    306.59470  24.98034
#
#    longitude  housePriceOfUnitArea  houseAgeStandardized
# 0  121.54024                   NaN              1.258245
# 1  121.53951                  42.2              0.164474

# %%
data.loc[0:2, 'title']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'title'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
data.loc[0:2, 'houseAge']
# Out:
# 0    0.730594
# 1    0.445205
# 2    0.303653
# Name: houseAge, dtype: float64

# %%
data.loc[0:10, :] ## List all rows from 0 to 10 index
# Out:
#     No  transactionDate  houseAge  distanceToNearestMRTstation  latitude  \
# 0    1         2012.917  0.730594                     84.87882  24.98298
# 1    2         2012.917  0.445205                    306.59470  24.98034
# 2    3         2013.583  0.303653                    561.98450  24.98746
# 3    4         2013.500  0.303653                    561.98450  24.98746
# 4    5         2012.833  0.114155                    390.56840  24.97937
# 5    6         2012.667  0.162100                   2175.03000  24.96305
# 6    7         2012.667  0.787671                    623.47310  24.97933
# 7    8         2013.417  0.463470                    287.60250  24.98042
# 8    9         2013.500  0.723744                   5512.03800  24.95095
# 9   10         2013.417  0.408676                   1783.18000  24.96731
# 10  11         2013.083  0.794521                    405.21340  24.97349
#
#     longitude  housePriceOfUnitArea  houseAgeStandardized
# ...

# %%
data.iloc[0, :]
# Out:
# No                                1.000000
# transactionDate                2012.917000
# houseAge                          0.730594
# distanceToNearestMRTstation      84.878820
# latitude                         24.982980
# longitude                       121.540240
# housePriceOfUnitArea                   NaN
# houseAgeStandardized              1.258245
# Name: 0, dtype: float64

# %%
data.iloc[0:3, :]
# Out:
#    No  transactionDate  houseAge  distanceToNearestMRTstation  latitude  \
# 0   1         2012.917  0.730594                     84.87882  24.98298
# 1   2         2012.917  0.445205                    306.59470  24.98034
# 2   3         2013.583  0.303653                    561.98450  24.98746
#
#    longitude  housePriceOfUnitArea  houseAgeStandardized
# 0  121.54024                   NaN              1.258245
# 1  121.53951                  42.2              0.164474
# 2  121.54391                  47.3             -0.378037

# %%
data.iloc[0:10, :] ## list all rows from 0 = 10 using iloc
# Out:
#    No  transactionDate  houseAge  distanceToNearestMRTstation  latitude  \
# 0   1         2012.917  0.730594                     84.87882  24.98298
# 1   2         2012.917  0.445205                    306.59470  24.98034
# 2   3         2013.583  0.303653                    561.98450  24.98746
# 3   4         2013.500  0.303653                    561.98450  24.98746
# 4   5         2012.833  0.114155                    390.56840  24.97937
# 5   6         2012.667  0.162100                   2175.03000  24.96305
# 6   7         2012.667  0.787671                    623.47310  24.97933
# 7   8         2013.417  0.463470                    287.60250  24.98042
# 8   9         2013.500  0.723744                   5512.03800  24.95095
# 9  10         2013.417  0.408676                   1783.18000  24.96731
#
#    longitude  housePriceOfUnitArea  houseAgeStandardized
# 0  121.54024                   NaN              1.258245
# 1  121.53951                  42.2              0.164474
# ...

# %%
data.drop_duplicates()
# Out:
#       No  transactionDate  houseAge  distanceToNearestMRTstation  latitude  \
# 0      1         2012.917  0.730594                     84.87882  24.98298
# 1      2         2012.917  0.445205                    306.59470  24.98034
# 2      3         2013.583  0.303653                    561.98450  24.98746
# 3      4         2013.500  0.303653                    561.98450  24.98746
# 4      5         2012.833  0.114155                    390.56840  24.97937
# ..   ...              ...       ...                          ...       ...
# 413  410         2013.000  0.312785                   4082.01500  24.94155
# 414  411         2012.667  0.127854                     90.45606  24.97433
# 415  412         2013.250  0.429224                    390.96960  24.97923
# 416  413         2013.000  0.184932                    104.81010  24.96674
# 417  414         2013.500  0.148402                     90.45606  24.97433
#
#      longitude  housePriceOfUnitArea  houseAgeStandardized
# ...

# %%
data.drop_duplicates(subset=['houseAge'])
# Out:
#       No  transactionDate  houseAge  distanceToNearestMRTstation  latitude  \
# 0      1         2012.917  0.730594                     84.87882  24.98298
# 1      2         2012.917  0.445205                    306.59470  24.98034
# 2      3         2013.583  0.303653                    561.98450  24.98746
# 4      5         2012.833  0.114155                    390.56840  24.97937
# 5      6         2012.667  0.162100                   2175.03000  24.96305
# ..   ...              ...       ...                          ...       ...
# 404  401         2013.250  0.611872                    482.75810  24.97433
# 405  402         2013.083  0.173516                   2175.03000  24.96305
# 410  407         2013.167  0.043379                    372.13860  24.97293
# 412  409         2013.417  0.422374                   2175.74400  24.96330
# 415  412         2013.250  0.429224                    390.96960  24.97923
#
#      longitude  housePriceOfUnitArea  houseAgeStandardized
# ...

# %%
data.drop_duplicates(subset=['latitude', 'longitude'])
# Out:
#       No  transactionDate  houseAge  distanceToNearestMRTstation  latitude  \
# 0      1         2012.917  0.730594                     84.87882  24.98298
# 1      2         2012.917  0.445205                    306.59470  24.98034
# 2      3         2013.583  0.303653                    561.98450  24.98746
# 4      5         2012.833  0.114155                    390.56840  24.97937
# 5      6         2012.667  0.162100                   2175.03000  24.96305
# ..   ...              ...       ...                          ...       ...
# 407  404         2012.667  0.705479                    161.94200  24.98353
# 409  406         2012.667  0.525114                    130.99450  24.95663
# 410  407         2013.167  0.043379                    372.13860  24.97293
# 412  409         2013.417  0.422374                   2175.74400  24.96330
# 415  412         2013.250  0.429224                    390.96960  24.97923
#
#      longitude  housePriceOfUnitArea  houseAgeStandardized
# ...

# %%
data.drop_duplicates(subset=['latitude', 'longitude'], inplace=True) #dropped duplicates by lat, long bc that seemed logical way to have unique index for duplicates

# %%
data.head()
# Out:
#    No  transactionDate  houseAge  distanceToNearestMRTstation  latitude  \
# 0   1         2012.917  0.730594                     84.87882  24.98298
# 1   2         2012.917  0.445205                    306.59470  24.98034
# 2   3         2013.583  0.303653                    561.98450  24.98746
# 4   5         2012.833  0.114155                    390.56840  24.97937
# 5   6         2012.667  0.162100                   2175.03000  24.96305
#
#    longitude  housePriceOfUnitArea  houseAgeStandardized
# 0  121.54024                   NaN              1.258245
# 1  121.53951                  42.2              0.164474
# 2  121.54391                  47.3             -0.378037
# 4  121.54245                  43.1             -1.104301
# 5  121.51254                  32.1             -0.920547

# %%
data
# Out:
#       No  transactionDate  houseAge  distanceToNearestMRTstation  latitude  \
# 0      1         2012.917  0.730594                     84.87882  24.98298
# 1      2         2012.917  0.445205                    306.59470  24.98034
# 2      3         2013.583  0.303653                    561.98450  24.98746
# 4      5         2012.833  0.114155                    390.56840  24.97937
# 5      6         2012.667  0.162100                   2175.03000  24.96305
# ..   ...              ...       ...                          ...       ...
# 407  404         2012.667  0.705479                    161.94200  24.98353
# 409  406         2012.667  0.525114                    130.99450  24.95663
# 410  407         2013.167  0.043379                    372.13860  24.97293
# 412  409         2013.417  0.422374                   2175.74400  24.96330
# 415  412         2013.250  0.429224                    390.96960  24.97923
#
#      longitude  housePriceOfUnitArea  houseAgeStandardized
# ...

# %%
data.fillna(0) #fill nan values with 0
# Out:
#       No  transactionDate  houseAge  distanceToNearestMRTstation  latitude  \
# 0      1         2012.917  0.730594                     84.87882  24.98298
# 1      2         2012.917  0.445205                    306.59470  24.98034
# 2      3         2013.583  0.303653                    561.98450  24.98746
# 4      5         2012.833  0.114155                    390.56840  24.97937
# 5      6         2012.667  0.162100                   2175.03000  24.96305
# ..   ...              ...       ...                          ...       ...
# 407  404         2012.667  0.705479                    161.94200  24.98353
# 409  406         2012.667  0.525114                    130.99450  24.95663
# 410  407         2013.167  0.043379                    372.13860  24.97293
# 412  409         2013.417  0.422374                   2175.74400  24.96330
# 415  412         2013.250  0.429224                    390.96960  24.97923
#
#      longitude  housePriceOfUnitArea  houseAgeStandardized
# ...

# %%
data.fillna(value=['housePriceOfUnitArea': 0])
# Out:
#   Cell In[77], line 1
#     data.fillna(value=['housePriceOfUnitArea': 0])
#                                              ^
# SyntaxError: invalid syntax

# %%
data.fillna(value=('housePriceOfUnitArea': 0)
# Out:
#   Cell In[78], line 1
#     data.fillna(value=('housePriceOfUnitArea': 0)
#                                              ^
# SyntaxError: invalid syntax

# %%
data.fillna(value=('housePriceOfUnitArea': 0))
# Out:
#   Cell In[79], line 1
#     data.fillna(value=('housePriceOfUnitArea': 0))
#                                              ^
# SyntaxError: invalid syntax

# %%
data.fillna(value={}'housePriceOfUnitArea': 0})
# Out:
#   Cell In[80], line 1
#     data.fillna(value={}'housePriceOfUnitArea': 0})
#                                                  ^
# SyntaxError: closing parenthesis '}' does not match opening parenthesis '('

# %%
# Out:
#       No  transactionDate  houseAge  distanceToNearestMRTstation  latitude  \
# 0      1         2012.917  0.730594                     84.87882  24.98298
# 1      2         2012.917  0.445205                    306.59470  24.98034
# 2      3         2013.583  0.303653                    561.98450  24.98746
# 4      5         2012.833  0.114155                    390.56840  24.97937
# 5      6         2012.667  0.162100                   2175.03000  24.96305
# ..   ...              ...       ...                          ...       ...
# 407  404         2012.667  0.705479                    161.94200  24.98353
# 409  406         2012.667  0.525114                    130.99450  24.95663
# 410  407         2013.167  0.043379                    372.13860  24.97293
# 412  409         2013.417  0.422374                   2175.74400  24.96330
# 415  412         2013.250  0.429224                    390.96960  24.97923
#
#      longitude  housePriceOfUnitArea  houseAgeStandardized
# ...

# %%
from numpy import nan ## here I was trying to find all strip all white space but I couldn't figure out how to do it for integers

# %%
data.replace({: {'': nan}})
# Out:
#   Cell In[83], line 1
#     data.replace({: {'': nan}})
#                   ^
# SyntaxError: invalid syntax

# %%
data.replace({'longitude': {'': nan}})
# Out:
#       No  transactionDate  houseAge  distanceToNearestMRTstation  latitude  \
# 0      1         2012.917  0.730594                     84.87882  24.98298
# 1      2         2012.917  0.445205                    306.59470  24.98034
# 2      3         2013.583  0.303653                    561.98450  24.98746
# 4      5         2012.833  0.114155                    390.56840  24.97937
# 5      6         2012.667  0.162100                   2175.03000  24.96305
# ..   ...              ...       ...                          ...       ...
# 407  404         2012.667  0.705479                    161.94200  24.98353
# 409  406         2012.667  0.525114                    130.99450  24.95663
# 410  407         2013.167  0.043379                    372.13860  24.97293
# 412  409         2013.417  0.422374                   2175.74400  24.96330
# 415  412         2013.250  0.429224                    390.96960  24.97923
#
#      longitude  housePriceOfUnitArea  houseAgeStandardized
# ...

# %%
data.replace({data.loc[0:]: {'': nan}})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[85], line 1
# ----> 1 data.replace({data.loc[0:]: {'': nan}})
#
# TypeError: unhashable type: 'DataFrame'

# %%
data.replace({data.loc[:]: {'': nan}})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[86], line 1
# ----> 1 data.replace({data.loc[:]: {'': nan}})
#
# TypeError: unhashable type: 'DataFrame'

# %%
data.loc[0:]
# Out:
#       No  transactionDate  houseAge  distanceToNearestMRTstation  latitude  \
# 0      1         2012.917  0.730594                     84.87882  24.98298
# 1      2         2012.917  0.445205                    306.59470  24.98034
# 2      3         2013.583  0.303653                    561.98450  24.98746
# 4      5         2012.833  0.114155                    390.56840  24.97937
# 5      6         2012.667  0.162100                   2175.03000  24.96305
# ..   ...              ...       ...                          ...       ...
# 407  404         2012.667  0.705479                    161.94200  24.98353
# 409  406         2012.667  0.525114                    130.99450  24.95663
# 410  407         2013.167  0.043379                    372.13860  24.97293
# 412  409         2013.417  0.422374                   2175.74400  24.96330
# 415  412         2013.250  0.429224                    390.96960  24.97923
#
#      longitude  housePriceOfUnitArea  houseAgeStandardized
# ...

# %%
data.replace({data.loc[0:]: {'': nan}})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[88], line 1
# ----> 1 data.replace({data.loc[0:]: {'': nan}})
#
# TypeError: unhashable type: 'DataFrame'

# %%
data.loc[data.title.str.contains('\s$', regex =True)]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[89], line 1
# ----> 1 data.loc[data.title.str.contains('\s$', regex =True)]
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'title'

# %%
data.loc[data.housePriceOfUnitArea.str.contains('\s$', regex =True)]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[90], line 1
# ----> 1 data.loc[data.housePriceOfUnitArea.str.contains('\s$', regex =True)]
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# File ~\anaconda3\lib\site-packages\pandas\core\accessor.py:182, in CachedAccessor.__get__(self, obj, cls)
#     179 if obj is None:
#     180     # we're accessing the attribute of the class, i.e., Dataset.geo
#     181     return self._accessor
# --> 182 accessor_obj = self._accessor(obj)
# ...

# %%
data.head()
# Out:
#    No  transactionDate  houseAge  distanceToNearestMRTstation  latitude  \
# 0   1         2012.917  0.730594                     84.87882  24.98298
# 1   2         2012.917  0.445205                    306.59470  24.98034
# 2   3         2013.583  0.303653                    561.98450  24.98746
# 4   5         2012.833  0.114155                    390.56840  24.97937
# 5   6         2012.667  0.162100                   2175.03000  24.96305
#
#    longitude  housePriceOfUnitArea  houseAgeStandardized
# 0  121.54024                   NaN              1.258245
# 1  121.53951                  42.2              0.164474
# 2  121.54391                  47.3             -0.378037
# 4  121.54245                  43.1             -1.104301
# 5  121.51254                  32.1             -0.920547

# %%
data.dtypes
# Out:
# No                               int64
# transactionDate                float64
# houseAge                       float64
# distanceToNearestMRTstation    float64
# latitude                       float64
# longitude                      float64
# housePriceOfUnitArea           float64
# houseAgeStandardized           float64
# dtype: object

# %%
data.loc[data.housePriceOfUnitArea.int.contains('\s$', regex =True)]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[93], line 1
# ----> 1 data.loc[data.housePriceOfUnitArea.int.contains('\s$', regex =True)]
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'int'

# %%
data.loc[data.title.str.contains('\s$', regex =True)]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[94], line 1
# ----> 1 data.loc[data.title.str.contains('\s$', regex =True)]
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'title'

# %%
data.head()
# Out:
#    No  transactionDate  houseAge  distanceToNearestMRTstation  latitude  \
# 0   1         2012.917  0.730594                     84.87882  24.98298
# 1   2         2012.917  0.445205                    306.59470  24.98034
# 2   3         2013.583  0.303653                    561.98450  24.98746
# 4   5         2012.833  0.114155                    390.56840  24.97937
# 5   6         2012.667  0.162100                   2175.03000  24.96305
#
#    longitude  housePriceOfUnitArea  houseAgeStandardized
# 0  121.54024                   NaN              1.258245
# 1  121.53951                  42.2              0.164474
# 2  121.54391                  47.3             -0.378037
# 4  121.54245                  43.1             -1.104301
# 5  121.51254                  32.1             -0.920547

# %%
data.fillna(mean())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[96], line 1
# ----> 1 data.fillna(mean())
#
# NameError: name 'mean' is not defined

# %%
data.fillna(data.mean())
# Out:
#       No  transactionDate  houseAge  distanceToNearestMRTstation  latitude  \
# 0      1         2012.917  0.730594                     84.87882  24.98298
# 1      2         2012.917  0.445205                    306.59470  24.98034
# 2      3         2013.583  0.303653                    561.98450  24.98746
# 4      5         2012.833  0.114155                    390.56840  24.97937
# 5      6         2012.667  0.162100                   2175.03000  24.96305
# ..   ...              ...       ...                          ...       ...
# 407  404         2012.667  0.705479                    161.94200  24.98353
# 409  406         2012.667  0.525114                    130.99450  24.95663
# 410  407         2013.167  0.043379                    372.13860  24.97293
# 412  409         2013.417  0.422374                   2175.74400  24.96330
# 415  412         2013.250  0.429224                    390.96960  24.97923
#
#      longitude  housePriceOfUnitArea  houseAgeStandardized
# ...

# %%
data.mean()
# Out:
# No                              185.887597
# transactionDate                2013.151504
# houseAge                          0.483717
# distanceToNearestMRTstation    1113.474881
# latitude                         24.969621
# longitude                       121.532935
# housePriceOfUnitArea             36.898047
# houseAgeStandardized              0.312074
# dtype: float64

# %%
data.head()
# Out:
#    No  transactionDate  houseAge  distanceToNearestMRTstation  latitude  \
# 0   1         2012.917  0.730594                     84.87882  24.98298
# 1   2         2012.917  0.445205                    306.59470  24.98034
# 2   3         2013.583  0.303653                    561.98450  24.98746
# 4   5         2012.833  0.114155                    390.56840  24.97937
# 5   6         2012.667  0.162100                   2175.03000  24.96305
#
#    longitude  housePriceOfUnitArea  houseAgeStandardized
# 0  121.54024                   NaN              1.258245
# 1  121.53951                  42.2              0.164474
# 2  121.54391                  47.3             -0.378037
# 4  121.54245                  43.1             -1.104301
# 5  121.51254                  32.1             -0.920547

# %%
data.fillna(data.mean())
# Out:
#       No  transactionDate  houseAge  distanceToNearestMRTstation  latitude  \
# 0      1         2012.917  0.730594                     84.87882  24.98298
# 1      2         2012.917  0.445205                    306.59470  24.98034
# 2      3         2013.583  0.303653                    561.98450  24.98746
# 4      5         2012.833  0.114155                    390.56840  24.97937
# 5      6         2012.667  0.162100                   2175.03000  24.96305
# ..   ...              ...       ...                          ...       ...
# 407  404         2012.667  0.705479                    161.94200  24.98353
# 409  406         2012.667  0.525114                    130.99450  24.95663
# 410  407         2013.167  0.043379                    372.13860  24.97293
# 412  409         2013.417  0.422374                   2175.74400  24.96330
# 415  412         2013.250  0.429224                    390.96960  24.97923
#
#      longitude  housePriceOfUnitArea  houseAgeStandardized
# ...

# %%
data.fillna(data.mean(), inplace=True) ##replace all NaN values with the mean of that column

# %%
data.head()
# Out:
#    No  transactionDate  houseAge  distanceToNearestMRTstation  latitude  \
# 0   1         2012.917  0.730594                     84.87882  24.98298
# 1   2         2012.917  0.445205                    306.59470  24.98034
# 2   3         2013.583  0.303653                    561.98450  24.98746
# 4   5         2012.833  0.114155                    390.56840  24.97937
# 5   6         2012.667  0.162100                   2175.03000  24.96305
#
#    longitude  housePriceOfUnitArea  houseAgeStandardized
# 0  121.54024             36.898047              1.258245
# 1  121.53951             42.200000              0.164474
# 2  121.54391             47.300000             -0.378037
# 4  121.54245             43.100000             -1.104301
# 5  121.51254             32.100000             -0.920547

# %%
name = 1

# %%
name = name1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[104], line 1
# ----> 1 name = name1
#
# NameError: name 'name1' is not defined

# %%
name1=2

# %%
name= name2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[106], line 1
# ----> 1 name= name2
#
# NameError: name 'name2' is not defined

# %%
name2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[107], line 1
# ----> 1 name2
#
# NameError: name 'name2' is not defined

# %%
name2 = 3

# %%
name1=name2

# %%
print(name1)
# Out:
# 3
