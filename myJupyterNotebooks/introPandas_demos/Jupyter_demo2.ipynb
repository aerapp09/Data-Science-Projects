# %%
import pandas as pd

# %%
data= pd.read_csv('customers.csv')

# %%
data.head()
# Out:
#   Customer Id    Customer Name                VIN        Location  \
# 0     CUS1008     Silvia Stone  1GCBS1941RP397653      Glen Allen
# 1     CUS1009        Billy Kid  1GCBS1941LK397654      Midlothian
# 2     CUS1014     Rita Skeeter  1GCBS1943FK397789      Woodbridge
# 3     CUS1015    Alastor Moody  1GKBS1941RK367993  Fredericksburg
# 4     CUS1016  Pansy Parkinson  1GCRS197FGK396789      Brandywine
#
#         Street Address State            City    Zip       Phone  \
# 0          123 Nope Dr    VA      Glen Allen  23060  8043462277
# 1        234B Leafy St    VA      Midlothian  23114  8043797264
# 2          2343 Blanco    VA      Woodbridge  22192  7035766550
# 3    643 Warzbach PKWY    VA  Fredericksburg  22407  5407107781
# 4  912 Silver Sands Dr    MD      Brandywine  20613  3017822942
#
#                    Email
# 0  SilviaStone@yahoo.com
# 1    Billy_Kid@gmail.com
# 2    RitaSkeeter@aol.com
# 3    Alastor23@gmail.com
# 4   PParkinson@gmail.com

# %%
data.sample()
# Out:
#   Customer Id Customer Name                VIN    Location Street Address  \
# 2     CUS1014  Rita Skeeter  1GCBS1943FK397789  Woodbridge    2343 Blanco
#
#   State        City    Zip       Phone                Email
# 2    VA  Woodbridge  22192  7035766550  RitaSkeeter@aol.com

# %%
data.pivot_table()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 data.pivot_table()
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:8731, in DataFrame.pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#    8714 @Substitution("")
#    8715 @Appender(_shared_docs["pivot_table"])
#    8716 def pivot_table(
#    (...)
#    8727     sort=True,
#    8728 ) -> DataFrame:
#    8729     from pandas.core.reshape.pivot import pivot_table
# -> 8731     return pivot_table(
#    8732         self,
#    8733         values=values,
#    8734         index=index,
#    8735         columns=columns,
#    8736         aggfunc=aggfunc,
#    8737         fill_value=fill_value,
#    8738         margins=margins,
#    8739         dropna=dropna,
#    8740         margins_name=margins_name,
# ...

# %%
data.head()
# Out:
#   Customer Id    Customer Name                VIN        Location  \
# 0     CUS1008     Silvia Stone  1GCBS1941RP397653      Glen Allen
# 1     CUS1009        Billy Kid  1GCBS1941LK397654      Midlothian
# 2     CUS1014     Rita Skeeter  1GCBS1943FK397789      Woodbridge
# 3     CUS1015    Alastor Moody  1GKBS1941RK367993  Fredericksburg
# 4     CUS1016  Pansy Parkinson  1GCRS197FGK396789      Brandywine
#
#         Street Address State            City    Zip       Phone  \
# 0          123 Nope Dr    VA      Glen Allen  23060  8043462277
# 1        234B Leafy St    VA      Midlothian  23114  8043797264
# 2          2343 Blanco    VA      Woodbridge  22192  7035766550
# 3    643 Warzbach PKWY    VA  Fredericksburg  22407  5407107781
# 4  912 Silver Sands Dr    MD      Brandywine  20613  3017822942
#
#                    Email
# 0  SilviaStone@yahoo.com
# 1    Billy_Kid@gmail.com
# 2    RitaSkeeter@aol.com
# 3    Alastor23@gmail.com
# 4   PParkinson@gmail.com

# %%
pd.pivot_table(df, index = ['Customer Name'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 pd.pivot_table(df, index = ['Customer Name'])
#
# NameError: name 'df' is not defined

# %%
pd.pivot_table(data, index = ['Customer Name'])
# Out:
# C:\Users\aerap\AppData\Local\Temp\ipykernel_15948\1491627970.py:1: FutureWarning: pivot_table dropped a column because it failed to aggregate. This behavior is deprecated and will raise in a future version of pandas. Select only the columns that can be aggregated.
#   pd.pivot_table(data, index = ['Customer Name'])
#                          Phone    Zip
# Customer Name
# Alastor Moody       5407107781  22407
# Albus Dumbeldor     4109317908  21030
# Billy Kid           8043797264  23114
# Cedric Diggory      7702638808  30071
# Cho Chang           8652187800  37934
# Draco Malfoy        3016048560  20723
# Ginny Weasley       4106963500  21043
# Harry Potter        3019479790  20877
# Hermione Granger    4109316500  21162
# Lily Potter         7034044386  20166
# Luna Lovegood       7705068484  30281
# Neville Longbottom  7702806200  30076
# Pansy Parkinson     3017822942  20613
# Rita Skeeter        7035766550  22192
# Ron Weasley         3016624380  21704
# ...

# %%
data.describe()
# Out:
#                 Zip         Phone
# count     20.000000  2.000000e+01
# mean   25624.100000  5.799188e+09
# std     5543.177579  2.225115e+09
# min    20166.000000  2.059851e+09
# 25%    21039.750000  3.835093e+09
# 50%    22733.500000  6.909433e+09
# 75%    30127.500000  7.705664e+09
# max    37934.000000  8.652188e+09

# %%
data.memory_usage()
# Out:
# Index             128
# Customer Id       160
# Customer Name     160
# VIN               160
# Location          160
# Street Address    160
# State             160
# City              160
# Zip               160
# Phone             160
# Email             160
# dtype: int64

# %%
data.sample()
# Out:
#    Customer Id   Customer Name                VIN  Location  \
# 15     CUS1027  Cedric Diggory  1GHGD1941RK334601  Norcross
#
#        Street Address State      City    Zip       Phone  \
# 15  90 Parsons Street    GA  Norcross  30071  7702638808
#
#                        Email
# 15  Cedric_Diggory@gmail.com
